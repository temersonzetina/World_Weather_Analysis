# %% [markdown]
# ### Deliverable 1: Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in /Users/anthonyemerson/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /Users/anthonyemerson/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 747

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=83830aa4eb962bc7a7782eb9d9e5b172

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 1 | vada
# Processing Record 4 of Set 1 | puerto ayora
# Processing Record 5 of Set 1 | mahadday weyne
# City not found. Skipping...
# Processing Record 6 of Set 1 | budogoshch
# Processing Record 7 of Set 1 | cape town
# Processing Record 8 of Set 1 | jasper
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | marsh harbour
# Processing Record 12 of Set 1 | mingguang
# Processing Record 13 of Set 1 | jamestown
# Processing Record 14 of Set 1 | magadan
# Processing Record 15 of Set 1 | chapais
# Processing Record 16 of Set 1 | richards bay
# Processing Record 17 of Set 1 | gaya
# Processing Record 18 of Set 1 | acapulco
# Processing Record 19 of Set 1 | mujiayingzi
# Processing Record 20 of Set 1 | pontianak
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | sao filipe
# Processing Record 24 of Set 1 | tucumcari
# Processing Record 25 of Set 1 | ballina
# Processing Record 26 of Set 1 | nome
# Processing Record 27 of Set 1 | yellowknife
# Processing Record 28 of Set 1 | teya
# Processing Record 29 of Set 1 | ternate
# Processing Record 30 of Set 1 | yomitan
# City not found. Skipping...
# Processing Record 31 of Set 1 | ribeira grande
# Processing Record 32 of Set 1 | falam
# Processing Record 33 of Set 1 | mae hong son
# Processing Record 34 of Set 1 | belyy yar
# Processing Record 35 of Set 1 | weligama
# Processing Record 36 of Set 1 | port elizabeth
# Processing Record 37 of Set 1 | guerrero negro
# Processing Record 38 of Set 1 | bambous virieux
# Processing Record 39 of Set 1 | harper
# Processing Record 40 of Set 1 | kidal
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | upernavik
# Processing Record 43 of Set 1 | leshukonskoye
# Processing Record 44 of Set 1 | perpignan
# Processing Record 45 of Set 1 | mar del plata
# Processing Record 46 of Set 1 | nizwa
# Processing Record 47 of Set 1 | port-gentil
# Processing Record 48 of Set 1 | mahebourg
# Processing Record 49 of Set 1 | barrow
# Processing Record 50 of Set 1 | jalu
# Processing Record 1 of Set 2 | amga
# Processing Record 2 of Set 2 | mount isa
# Processing Record 3 of Set 2 | riyadh
# Processing Record 4 of Set 2 | puerto madryn
# Processing Record 5 of Set 2 | castro
# Processing Record 6 of Set 2 | constantine
# Processing Record 7 of Set 2 | port alfred
# Processing Record 8 of Set 2 | sargatskoye
# Processing Record 9 of Set 2 | muswellbrook
# Processing Record 10 of Set 2 | saint-augustin
# Processing Record 11 of Set 2 | new norfolk
# Processing Record 12 of Set 2 | springbok
# Processing Record 13 of Set 2 | abhar
# Processing Record 14 of Set 2 | balkhash
# Processing Record 15 of Set 2 | kutum
# Processing Record 16 of Set 2 | hermanus
# Processing Record 17 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 2 | vigrestad
# Processing Record 19 of Set 2 | sevsk
# Processing Record 20 of Set 2 | provideniya
# Processing Record 21 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 2 | te anau
# Processing Record 23 of Set 2 | chicama
# Processing Record 24 of Set 2 | traverse city
# Processing Record 25 of Set 2 | aginskoye
# Processing Record 26 of Set 2 | akdepe
# Processing Record 27 of Set 2 | marmora
# Processing Record 28 of Set 2 | kirkcudbright
# Processing Record 29 of Set 2 | keti bandar
# Processing Record 30 of Set 2 | mogadishu
# Processing Record 31 of Set 2 | middelburg
# Processing Record 32 of Set 2 | goderich
# Processing Record 33 of Set 2 | talnakh
# Processing Record 34 of Set 2 | hilo
# Processing Record 35 of Set 2 | winterberg
# Processing Record 36 of Set 2 | ancud
# Processing Record 37 of Set 2 | mount gambier
# Processing Record 38 of Set 2 | olafsvik
# Processing Record 39 of Set 2 | ponta do sol
# Processing Record 40 of Set 2 | eyl
# Processing Record 41 of Set 2 | dikson
# Processing Record 42 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 2 | turukhansk
# Processing Record 44 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 2 | beaverlodge
# Processing Record 46 of Set 2 | mapiripan
# Processing Record 47 of Set 2 | avarua
# Processing Record 48 of Set 2 | vaitape
# Processing Record 49 of Set 2 | kaitangata
# Processing Record 50 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 3 | cayenne
# Processing Record 2 of Set 3 | san-pedro
# Processing Record 3 of Set 3 | beringovskiy
# Processing Record 4 of Set 3 | kapaa
# Processing Record 5 of Set 3 | kaz
# Processing Record 6 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 3 | gamba
# Processing Record 8 of Set 3 | umred
# Processing Record 9 of Set 3 | thompson
# Processing Record 10 of Set 3 | bafra
# Processing Record 11 of Set 3 | conceicao da barra
# Processing Record 12 of Set 3 | ariquemes
# Processing Record 13 of Set 3 | zyryanka
# Processing Record 14 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 16 of Set 3 | kalianget
# Processing Record 17 of Set 3 | khatanga
# Processing Record 18 of Set 3 | esperance
# Processing Record 19 of Set 3 | atuona
# Processing Record 20 of Set 3 | leningradskiy
# Processing Record 21 of Set 3 | lagoa
# Processing Record 22 of Set 3 | palembang
# Processing Record 23 of Set 3 | namatanai
# Processing Record 24 of Set 3 | callaway
# Processing Record 25 of Set 3 | dingle
# Processing Record 26 of Set 3 | kununurra
# Processing Record 27 of Set 3 | saint-philippe
# Processing Record 28 of Set 3 | hofn
# Processing Record 29 of Set 3 | farafangana
# Processing Record 30 of Set 3 | butaritari
# Processing Record 31 of Set 3 | san cristobal
# Processing Record 32 of Set 3 | cockburn town
# Processing Record 33 of Set 3 | bandarbeyla
# Processing Record 34 of Set 3 | tonj
# Processing Record 35 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 36 of Set 3 | nikolskoye
# Processing Record 37 of Set 3 | kawalu
# Processing Record 38 of Set 3 | meilu
# City not found. Skipping...
# Processing Record 39 of Set 3 | haines junction
# Processing Record 40 of Set 3 | kruisfontein
# Processing Record 41 of Set 3 | santa fe
# Processing Record 42 of Set 3 | lompoc
# Processing Record 43 of Set 3 | koslan
# Processing Record 44 of Set 3 | chara
# Processing Record 45 of Set 3 | doaba
# Processing Record 46 of Set 3 | gazanjyk
# Processing Record 47 of Set 3 | kodiak
# Processing Record 48 of Set 3 | sorland
# Processing Record 49 of Set 3 | lucapa
# Processing Record 50 of Set 3 | cidreira
# Processing Record 1 of Set 4 | faanui
# Processing Record 2 of Set 4 | okhotsk
# Processing Record 3 of Set 4 | san patricio
# Processing Record 4 of Set 4 | sharlyk
# Processing Record 5 of Set 4 | sioux lookout
# Processing Record 6 of Set 4 | urucui
# Processing Record 7 of Set 4 | havelock
# Processing Record 8 of Set 4 | utete
# Processing Record 9 of Set 4 | east millcreek
# Processing Record 10 of Set 4 | cherdyn
# Processing Record 11 of Set 4 | bredasdorp
# Processing Record 12 of Set 4 | rikitea
# Processing Record 13 of Set 4 | chilpancingo
# Processing Record 14 of Set 4 | letnyaya stavka
# Processing Record 15 of Set 4 | albany
# Processing Record 16 of Set 4 | seoul
# Processing Record 17 of Set 4 | iset
# Processing Record 18 of Set 4 | trindade
# Processing Record 19 of Set 4 | hobart
# Processing Record 20 of Set 4 | georgetown
# Processing Record 21 of Set 4 | kerema
# Processing Record 22 of Set 4 | comodoro rivadavia
# Processing Record 23 of Set 4 | tasiilaq
# Processing Record 24 of Set 4 | bandrele
# Processing Record 25 of Set 4 | qaanaaq
# Processing Record 26 of Set 4 | iquitos
# Processing Record 27 of Set 4 | salinas
# Processing Record 28 of Set 4 | turtas
# Processing Record 29 of Set 4 | brae
# Processing Record 30 of Set 4 | carnarvon
# Processing Record 31 of Set 4 | taltal
# Processing Record 32 of Set 4 | coquimbo
# Processing Record 33 of Set 4 | hualmay
# Processing Record 34 of Set 4 | shumyachi
# Processing Record 35 of Set 4 | new richmond
# Processing Record 36 of Set 4 | bud
# Processing Record 37 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 4 | lebu
# Processing Record 39 of Set 4 | malakal
# Processing Record 40 of Set 4 | shu
# Processing Record 41 of Set 4 | saskylakh
# Processing Record 42 of Set 4 | novyy urengoy
# Processing Record 43 of Set 4 | wolmaranstad
# City not found. Skipping...
# Processing Record 44 of Set 4 | gushikawa
# Processing Record 45 of Set 4 | boyolangu
# Processing Record 46 of Set 4 | vao
# Processing Record 47 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 48 of Set 4 | washington
# Processing Record 49 of Set 4 | sechura
# Processing Record 50 of Set 4 | east london
# Processing Record 1 of Set 5 | krasnoselkup
# Processing Record 2 of Set 5 | sitka
# Processing Record 3 of Set 5 | manzhouli
# Processing Record 4 of Set 5 | torbay
# Processing Record 5 of Set 5 | meulaboh
# Processing Record 6 of Set 5 | iqaluit
# Processing Record 7 of Set 5 | tuatapere
# Processing Record 8 of Set 5 | notre-dame-du-lac
# Processing Record 9 of Set 5 | sao joao da barra
# Processing Record 10 of Set 5 | zhuanghe
# Processing Record 11 of Set 5 | cortez
# Processing Record 12 of Set 5 | arraial do cabo
# Processing Record 13 of Set 5 | la ronge
# Processing Record 14 of Set 5 | dubenskiy
# City not found. Skipping...
# Processing Record 15 of Set 5 | hvide sande
# Processing Record 16 of Set 5 | providencia
# Processing Record 17 of Set 5 | plettenberg bay
# Processing Record 18 of Set 5 | martapura
# Processing Record 19 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 20 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 5 | faya
# Processing Record 22 of Set 5 | pisco
# Processing Record 23 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 5 | clyde river
# Processing Record 25 of Set 5 | tezu
# Processing Record 26 of Set 5 | moussoro
# Processing Record 27 of Set 5 | saint george
# Processing Record 28 of Set 5 | slobozia
# Processing Record 29 of Set 5 | beira
# Processing Record 30 of Set 5 | santander jimenez
# Processing Record 31 of Set 5 | ahipara
# Processing Record 32 of Set 5 | norman wells
# Processing Record 33 of Set 5 | murray bridge
# Processing Record 34 of Set 5 | saint-pierre
# Processing Record 35 of Set 5 | hasaki
# Processing Record 36 of Set 5 | tanout
# Processing Record 37 of Set 5 | ende
# Processing Record 38 of Set 5 | soria
# Processing Record 39 of Set 5 | bam
# Processing Record 40 of Set 5 | okato
# Processing Record 41 of Set 5 | darnah
# Processing Record 42 of Set 5 | tateyama
# Processing Record 43 of Set 5 | colonelganj
# Processing Record 44 of Set 5 | tuktoyaktuk
# Processing Record 45 of Set 5 | norrkoping
# Processing Record 46 of Set 5 | contamana
# Processing Record 47 of Set 5 | pevek
# Processing Record 48 of Set 5 | sukhinichi
# Processing Record 49 of Set 5 | chuy
# Processing Record 50 of Set 5 | the valley
# Processing Record 1 of Set 6 | maltahohe
# Processing Record 2 of Set 6 | severo-kurilsk
# Processing Record 3 of Set 6 | victoria
# Processing Record 4 of Set 6 | longyearbyen
# Processing Record 5 of Set 6 | gandhidham
# Processing Record 6 of Set 6 | ketchikan
# Processing Record 7 of Set 6 | flinders
# Processing Record 8 of Set 6 | san luis
# Processing Record 9 of Set 6 | sembakung
# Processing Record 10 of Set 6 | hithadhoo
# Processing Record 11 of Set 6 | waipawa
# Processing Record 12 of Set 6 | yulara
# Processing Record 13 of Set 6 | along
# Processing Record 14 of Set 6 | griffith
# Processing Record 15 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 6 | san fernando
# Processing Record 17 of Set 6 | triunfo
# Processing Record 18 of Set 6 | nemuro
# Processing Record 19 of Set 6 | ust-maya
# Processing Record 20 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 21 of Set 6 | two rivers
# Processing Record 22 of Set 6 | praia da vitoria
# Processing Record 23 of Set 6 | katsuura
# Processing Record 24 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 6 | kaeo
# Processing Record 26 of Set 6 | saldanha
# Processing Record 27 of Set 6 | puerto carreno
# Processing Record 28 of Set 6 | qazax
# Processing Record 29 of Set 6 | zeerust
# Processing Record 30 of Set 6 | dagana
# Processing Record 31 of Set 6 | marawi
# Processing Record 32 of Set 6 | zhuhai
# Processing Record 33 of Set 6 | sao gabriel da cachoeira
# Processing Record 34 of Set 6 | dolinsk
# Processing Record 35 of Set 6 | cermik
# Processing Record 36 of Set 6 | vardo
# Processing Record 37 of Set 6 | la seyne-sur-mer
# Processing Record 38 of Set 6 | hambantota
# Processing Record 39 of Set 6 | tiksi
# Processing Record 40 of Set 6 | makakilo city
# Processing Record 41 of Set 6 | paamiut
# Processing Record 42 of Set 6 | liwale
# Processing Record 43 of Set 6 | husavik
# Processing Record 44 of Set 6 | labuhan
# Processing Record 45 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 6 | sao miguel do araguaia
# Processing Record 47 of Set 6 | lorengau
# Processing Record 48 of Set 6 | atambua
# Processing Record 49 of Set 6 | portland
# Processing Record 50 of Set 6 | senneterre
# Processing Record 1 of Set 7 | dong hoi
# Processing Record 2 of Set 7 | bowen
# Processing Record 3 of Set 7 | coihaique
# Processing Record 4 of Set 7 | qadirpur ran
# Processing Record 5 of Set 7 | tagusao
# Processing Record 6 of Set 7 | burgeo
# Processing Record 7 of Set 7 | alofi
# Processing Record 8 of Set 7 | sitio novo do tocantins
# Processing Record 9 of Set 7 | halifax
# Processing Record 10 of Set 7 | jinchengjiang
# City not found. Skipping...
# Processing Record 11 of Set 7 | yerbogachen
# Processing Record 12 of Set 7 | grobina
# Processing Record 13 of Set 7 | suzu
# City not found. Skipping...
# Processing Record 14 of Set 7 | laguna
# Processing Record 15 of Set 7 | lakselv
# Processing Record 16 of Set 7 | port hardy
# Processing Record 17 of Set 7 | omsukchan
# Processing Record 18 of Set 7 | conde
# Processing Record 19 of Set 7 | shakiso
# Processing Record 20 of Set 7 | yenagoa
# Processing Record 21 of Set 7 | fortuna
# Processing Record 22 of Set 7 | khorixas
# Processing Record 23 of Set 7 | mountain home
# Processing Record 24 of Set 7 | caravelas
# Processing Record 25 of Set 7 | santo domingo
# Processing Record 26 of Set 7 | nanortalik
# Processing Record 27 of Set 7 | yeppoon
# Processing Record 28 of Set 7 | taoudenni
# Processing Record 29 of Set 7 | half moon bay
# Processing Record 30 of Set 7 | djougou
# Processing Record 31 of Set 7 | solsvik
# City not found. Skipping...
# Processing Record 32 of Set 7 | sola
# Processing Record 33 of Set 7 | cockburn harbour
# City not found. Skipping...
# Processing Record 34 of Set 7 | awbari
# Processing Record 35 of Set 7 | airai
# Processing Record 36 of Set 7 | cabo san lucas
# Processing Record 37 of Set 7 | gogrial
# Processing Record 38 of Set 7 | srednekolymsk
# Processing Record 39 of Set 7 | galgamacsa
# Processing Record 40 of Set 7 | sergeyevka
# Processing Record 41 of Set 7 | mentok
# City not found. Skipping...
# Processing Record 42 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 43 of Set 7 | egvekinot
# Processing Record 44 of Set 7 | vostok
# Processing Record 45 of Set 7 | palmer
# Processing Record 46 of Set 7 | kavieng
# Processing Record 47 of Set 7 | ocampo
# Processing Record 48 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 7 | port blair
# Processing Record 50 of Set 7 | kalmunai
# Processing Record 1 of Set 8 | biak
# Processing Record 2 of Set 8 | kahului
# Processing Record 3 of Set 8 | athabasca
# Processing Record 4 of Set 8 | imbituba
# Processing Record 5 of Set 8 | gari
# Processing Record 6 of Set 8 | broken hill
# Processing Record 7 of Set 8 | ishigaki
# Processing Record 8 of Set 8 | ostrovnoy
# Processing Record 9 of Set 8 | odweyne
# Processing Record 10 of Set 8 | bathsheba
# Processing Record 11 of Set 8 | tukrah
# Processing Record 12 of Set 8 | buala
# Processing Record 13 of Set 8 | lavrentiya
# Processing Record 14 of Set 8 | iranshahr
# Processing Record 15 of Set 8 | bajram curri
# Processing Record 16 of Set 8 | aklavik
# Processing Record 17 of Set 8 | raudeberg
# Processing Record 18 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 8 | bosaso
# Processing Record 20 of Set 8 | anadyr
# Processing Record 21 of Set 8 | nelas
# Processing Record 22 of Set 8 | inndyr
# Processing Record 23 of Set 8 | tautira
# Processing Record 24 of Set 8 | rawson
# Processing Record 25 of Set 8 | aksha
# Processing Record 26 of Set 8 | san francisco
# Processing Record 27 of Set 8 | vysokogornyy
# Processing Record 28 of Set 8 | cherskiy
# Processing Record 29 of Set 8 | lukulu
# Processing Record 30 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 31 of Set 8 | morro bay
# Processing Record 32 of Set 8 | topeka
# Processing Record 33 of Set 8 | souillac
# Processing Record 34 of Set 8 | westport
# Processing Record 35 of Set 8 | savelugu
# Processing Record 36 of Set 8 | kismayo
# Processing Record 37 of Set 8 | arequipa
# Processing Record 38 of Set 8 | antofagasta
# Processing Record 39 of Set 8 | rio verde de mato grosso
# Processing Record 40 of Set 8 | bloomington
# Processing Record 41 of Set 8 | touros
# Processing Record 42 of Set 8 | pondicherry
# Processing Record 43 of Set 8 | lewiston
# Processing Record 44 of Set 8 | tuburan
# Processing Record 45 of Set 8 | narsaq
# Processing Record 46 of Set 8 | broome
# Processing Record 47 of Set 8 | guajara-mirim
# City not found. Skipping...
# Processing Record 48 of Set 8 | severo-yeniseyskiy
# Processing Record 49 of Set 8 | kenai
# Processing Record 50 of Set 8 | jabiru
# City not found. Skipping...
# Processing Record 1 of Set 9 | sibolga
# Processing Record 2 of Set 9 | lerwick
# Processing Record 3 of Set 9 | aksu
# Processing Record 4 of Set 9 | samana
# Processing Record 5 of Set 9 | luganville
# Processing Record 6 of Set 9 | ruthin
# Processing Record 7 of Set 9 | floro
# Processing Record 8 of Set 9 | sinnamary
# Processing Record 9 of Set 9 | kalmar
# Processing Record 10 of Set 9 | chokurdakh
# Processing Record 11 of Set 9 | nacala
# Processing Record 12 of Set 9 | yar-sale
# Processing Record 13 of Set 9 | baijiantan
# Processing Record 14 of Set 9 | kirillov
# Processing Record 15 of Set 9 | zabol
# Processing Record 16 of Set 9 | jiayuguan
# Processing Record 17 of Set 9 | bethel
# Processing Record 18 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 19 of Set 9 | vanimo
# Processing Record 20 of Set 9 | sisimiut
# Processing Record 21 of Set 9 | kalabo
# Processing Record 22 of Set 9 | stornoway
# Processing Record 23 of Set 9 | veghel
# Processing Record 24 of Set 9 | newport
# Processing Record 25 of Set 9 | shetpe
# Processing Record 26 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 27 of Set 9 | bilma
# Processing Record 28 of Set 9 | nogliki
# Processing Record 29 of Set 9 | bangangte
# Processing Record 30 of Set 9 | ciudad guayana
# Processing Record 31 of Set 9 | tymovskoye
# Processing Record 32 of Set 9 | el balyana
# City not found. Skipping...
# Processing Record 33 of Set 9 | kulachi
# Processing Record 34 of Set 9 | canelli
# Processing Record 35 of Set 9 | pacific grove
# Processing Record 36 of Set 9 | baruun-urt
# Processing Record 37 of Set 9 | asau
# Processing Record 38 of Set 9 | ginir
# Processing Record 39 of Set 9 | bogande
# Processing Record 40 of Set 9 | caluquembe
# Processing Record 41 of Set 9 | sale
# Processing Record 42 of Set 9 | kuching
# Processing Record 43 of Set 9 | santa isabel do rio negro
# Processing Record 44 of Set 9 | hovd
# Processing Record 45 of Set 9 | ornskoldsvik
# Processing Record 46 of Set 9 | chalchihuites
# Processing Record 47 of Set 9 | verkhnevilyuysk
# Processing Record 48 of Set 9 | abidjan
# Processing Record 49 of Set 9 | omboue
# Processing Record 50 of Set 9 | isangel
# Processing Record 1 of Set 10 | razole
# Processing Record 2 of Set 10 | coari
# Processing Record 3 of Set 10 | santiago del estero
# Processing Record 4 of Set 10 | bay roberts
# Processing Record 5 of Set 10 | mangrol
# Processing Record 6 of Set 10 | kytlym
# City not found. Skipping...
# Processing Record 7 of Set 10 | ihosy
# Processing Record 8 of Set 10 | gallup
# Processing Record 9 of Set 10 | tiruchchendur
# Processing Record 10 of Set 10 | hua hin
# Processing Record 11 of Set 10 | winnemucca
# Processing Record 12 of Set 10 | matagami
# Processing Record 13 of Set 10 | khanu woralaksaburi
# Processing Record 14 of Set 10 | rivera
# Processing Record 15 of Set 10 | san ramon
# Processing Record 16 of Set 10 | honningsvag
# Processing Record 17 of Set 10 | saint-georges
# Processing Record 18 of Set 10 | sur
# Processing Record 19 of Set 10 | padang
# Processing Record 20 of Set 10 | makarov
# Processing Record 21 of Set 10 | bairiki
# Processing Record 22 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 10 | carauari
# Processing Record 24 of Set 10 | saryg-sep
# Processing Record 25 of Set 10 | rundu
# Processing Record 26 of Set 10 | la asuncion
# Processing Record 27 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 10 | takoradi
# Processing Record 29 of Set 10 | milkovo
# Processing Record 30 of Set 10 | san lazaro
# Processing Record 31 of Set 10 | lyuban
# Processing Record 32 of Set 10 | vila velha
# Processing Record 33 of Set 10 | komsomolskiy
# Processing Record 34 of Set 10 | port hedland
# Processing Record 35 of Set 10 | tamiahua
# Processing Record 36 of Set 10 | nikki
# Processing Record 37 of Set 10 | liuzhou
# Processing Record 38 of Set 10 | gat
# Processing Record 39 of Set 10 | tabialan
# City not found. Skipping...
# Processing Record 40 of Set 10 | whitehorse
# Processing Record 41 of Set 10 | tsogni
# Processing Record 42 of Set 10 | saint-max
# Processing Record 43 of Set 10 | lanciano
# Processing Record 44 of Set 10 | samarai
# Processing Record 45 of Set 10 | baoding
# Processing Record 46 of Set 10 | tiznit
# Processing Record 47 of Set 10 | oktyabrskiy
# Processing Record 48 of Set 10 | ilovlya
# Processing Record 49 of Set 10 | madoc
# Processing Record 50 of Set 10 | sorong
# Processing Record 1 of Set 11 | palu
# Processing Record 2 of Set 11 | methala
# Processing Record 3 of Set 11 | coracao de jesus
# Processing Record 4 of Set 11 | zavodoukovsk
# Processing Record 5 of Set 11 | havre-saint-pierre
# Processing Record 6 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 7 of Set 11 | lata
# Processing Record 8 of Set 11 | orebro
# Processing Record 9 of Set 11 | suluq
# Processing Record 10 of Set 11 | panjwin
# City not found. Skipping...
# Processing Record 11 of Set 11 | mayumba
# Processing Record 12 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 13 of Set 11 | deputatskiy
# Processing Record 14 of Set 11 | dumka
# Processing Record 15 of Set 11 | qrendi
# Processing Record 16 of Set 11 | siayan
# Processing Record 17 of Set 11 | santa maria
# Processing Record 18 of Set 11 | surt
# Processing Record 19 of Set 11 | aasiaat
# Processing Record 20 of Set 11 | warrington
# Processing Record 21 of Set 11 | glendive
# Processing Record 22 of Set 11 | bom despacho
# Processing Record 23 of Set 11 | ambilobe
# Processing Record 24 of Set 11 | gashua
# Processing Record 25 of Set 11 | san buenaventura
# Processing Record 26 of Set 11 | svetlogorsk
# Processing Record 27 of Set 11 | avera
# Processing Record 28 of Set 11 | bang krathum
# Processing Record 29 of Set 11 | bengkulu
# Processing Record 30 of Set 11 | bukama
# Processing Record 31 of Set 11 | kantunilkin
# Processing Record 32 of Set 11 | zhanatas
# City not found. Skipping...
# Processing Record 33 of Set 11 | mishan
# Processing Record 34 of Set 11 | mimongo
# Processing Record 35 of Set 11 | jalingo
# Processing Record 36 of Set 11 | jiuquan
# Processing Record 37 of Set 11 | alta floresta
# Processing Record 38 of Set 11 | orlik
# Processing Record 39 of Set 11 | port lincoln
# Processing Record 40 of Set 11 | grindavik
# Processing Record 41 of Set 11 | lasa
# Processing Record 42 of Set 11 | orsha
# Processing Record 43 of Set 11 | quimper
# Processing Record 44 of Set 11 | umm lajj
# Processing Record 45 of Set 11 | kabompo
# Processing Record 46 of Set 11 | alyangula
# Processing Record 47 of Set 11 | porto novo
# Processing Record 48 of Set 11 | mbanza-ngungu
# Processing Record 49 of Set 11 | santo antonio do sudoeste
# Processing Record 50 of Set 11 | tyup
# Processing Record 1 of Set 12 | bontang
# Processing Record 2 of Set 12 | togur
# Processing Record 3 of Set 12 | dicabisagan
# Processing Record 4 of Set 12 | karratha
# Processing Record 5 of Set 12 | freeport
# Processing Record 6 of Set 12 | horki
# Processing Record 7 of Set 12 | mahibadhoo
# Processing Record 8 of Set 12 | luderitz
# Processing Record 9 of Set 12 | nabire
# Processing Record 10 of Set 12 | kindersley
# Processing Record 11 of Set 12 | tura
# Processing Record 12 of Set 12 | borogontsy
# Processing Record 13 of Set 12 | gorontalo
# Processing Record 14 of Set 12 | soyo
# Processing Record 15 of Set 12 | pedernales
# Processing Record 16 of Set 12 | nishihara
# Processing Record 17 of Set 12 | ostersund
# Processing Record 18 of Set 12 | saint anthony
# Processing Record 19 of Set 12 | charters towers
# Processing Record 20 of Set 12 | belaya gora
# Processing Record 21 of Set 12 | palauig
# Processing Record 22 of Set 12 | andevoranto
# City not found. Skipping...
# Processing Record 23 of Set 12 | sakete
# Processing Record 24 of Set 12 | rosaryville
# Processing Record 25 of Set 12 | kieta
# Processing Record 26 of Set 12 | salisbury
# Processing Record 27 of Set 12 | arroio grande
# Processing Record 28 of Set 12 | carutapera
# Processing Record 29 of Set 12 | ordzhonikidze
# Processing Record 30 of Set 12 | poum
# Processing Record 31 of Set 12 | solnechnyy
# Processing Record 32 of Set 12 | payo
# Processing Record 33 of Set 12 | norfolk
# Processing Record 34 of Set 12 | basco
# Processing Record 35 of Set 12 | vestmannaeyjar
# Processing Record 36 of Set 12 | luau
# Processing Record 37 of Set 12 | povenets
# Processing Record 38 of Set 12 | da nang
# Processing Record 39 of Set 12 | necochea
# Processing Record 40 of Set 12 | ixtapa
# Processing Record 41 of Set 12 | nuuk
# Processing Record 42 of Set 12 | sabinopolis
# Processing Record 43 of Set 12 | wahiawa
# Processing Record 44 of Set 12 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 45 of Set 12 | itoman
# Processing Record 46 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 47 of Set 12 | pasighat
# Processing Record 48 of Set 12 | grand gaube
# Processing Record 49 of Set 12 | camacha
# Processing Record 50 of Set 12 | hay river
# Processing Record 1 of Set 13 | khandyga
# Processing Record 2 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 3 of Set 13 | russell
# Processing Record 4 of Set 13 | pucallpa
# Processing Record 5 of Set 13 | darhan
# Processing Record 6 of Set 13 | baracoa
# Processing Record 7 of Set 13 | monte alegre
# Processing Record 8 of Set 13 | minab
# Processing Record 9 of Set 13 | paengaroa
# Processing Record 10 of Set 13 | houston
# Processing Record 11 of Set 13 | pangnirtung
# Processing Record 12 of Set 13 | blyth
# Processing Record 13 of Set 13 | amantea
# Processing Record 14 of Set 13 | cotonou
# Processing Record 15 of Set 13 | eureka
# Processing Record 16 of Set 13 | sambava
# Processing Record 17 of Set 13 | diego de almagro
# Processing Record 18 of Set 13 | nyurba
# Processing Record 19 of Set 13 | severomuysk
# Processing Record 20 of Set 13 | alekseyevka
# Processing Record 21 of Set 13 | quelimane
# Processing Record 22 of Set 13 | mount pleasant
# Processing Record 23 of Set 13 | waitati
# Processing Record 24 of Set 13 | alappuzha
# Processing Record 25 of Set 13 | saraland
# Processing Record 26 of Set 13 | aloleng
# Processing Record 27 of Set 13 | fairbanks
# Processing Record 28 of Set 13 | berlevag
# Processing Record 29 of Set 13 | almaznyy
# Processing Record 30 of Set 13 | pachino
# Processing Record 31 of Set 13 | burica
# City not found. Skipping...
# Processing Record 32 of Set 13 | ilulissat
# Processing Record 33 of Set 13 | matara
# Processing Record 34 of Set 13 | qaqortoq
# Processing Record 35 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 37 of Set 13 | puri
# Processing Record 38 of Set 13 | harnai
# Processing Record 39 of Set 13 | langham
# Processing Record 40 of Set 13 | barao de melgaco
# Processing Record 41 of Set 13 | jian
# Processing Record 42 of Set 13 | san miguel
# Processing Record 43 of Set 13 | ukholovo
# Processing Record 44 of Set 13 | constitucion
# Processing Record 45 of Set 13 | moultrie
# Processing Record 46 of Set 13 | terre-de-bas
# Processing Record 47 of Set 13 | vila
# Processing Record 48 of Set 13 | kangaatsiaq
# Processing Record 49 of Set 13 | yashkul
# Processing Record 50 of Set 13 | ulaangom
# Processing Record 1 of Set 14 | dwarka
# Processing Record 2 of Set 14 | liverpool
# Processing Record 3 of Set 14 | rabaul
# Processing Record 4 of Set 14 | emba
# Processing Record 5 of Set 14 | marsaxlokk
# Processing Record 6 of Set 14 | janfida
# Processing Record 7 of Set 14 | santa lucia
# Processing Record 8 of Set 14 | great yarmouth
# Processing Record 9 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 10 of Set 14 | smithers
# Processing Record 11 of Set 14 | vangaindrano
# Processing Record 12 of Set 14 | skibbereen
# Processing Record 13 of Set 14 | alice
# Processing Record 14 of Set 14 | mollendo
# Processing Record 15 of Set 14 | beisfjord
# Processing Record 16 of Set 14 | zheleznodorozhnyy
# Processing Record 17 of Set 14 | tarpon springs
# Processing Record 18 of Set 14 | jieshi
# Processing Record 19 of Set 14 | aykhal
# Processing Record 20 of Set 14 | asosa
# Processing Record 21 of Set 14 | oussouye
# Processing Record 22 of Set 14 | neosho
# Processing Record 23 of Set 14 | codrington
# Processing Record 24 of Set 14 | burnie
# Processing Record 25 of Set 14 | achisay
# City not found. Skipping...
# Processing Record 26 of Set 14 | morros
# Processing Record 27 of Set 14 | mehamn
# Processing Record 28 of Set 14 | mocuba
# Processing Record 29 of Set 14 | honiara
# Processing Record 30 of Set 14 | trinidad
# Processing Record 31 of Set 14 | vernon
# Processing Record 32 of Set 14 | ejura
# Processing Record 33 of Set 14 | madang
# Processing Record 34 of Set 14 | sistranda
# Processing Record 35 of Set 14 | tsuruga
# Processing Record 36 of Set 14 | burns lake
# Processing Record 37 of Set 14 | concepcion del oro
# Processing Record 38 of Set 14 | katangli
# Processing Record 39 of Set 14 | cape canaveral
# Processing Record 40 of Set 14 | college
# Processing Record 41 of Set 14 | vila franca do campo
# Processing Record 42 of Set 14 | ivolginsk
# Processing Record 43 of Set 14 | klaksvik
# Processing Record 44 of Set 14 | piacabucu
# Processing Record 45 of Set 14 | deh rawud
# City not found. Skipping...
# Processing Record 46 of Set 14 | ghanzi
# Processing Record 47 of Set 14 | kichera
# Processing Record 48 of Set 14 | laramie
# Processing Record 49 of Set 14 | teahupoo
# Processing Record 50 of Set 14 | primorka
# Processing Record 1 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 15 | rocha
# Processing Record 3 of Set 15 | uwajima
# Processing Record 4 of Set 15 | magdagachi
# Processing Record 5 of Set 15 | zabaykalsk
# Processing Record 6 of Set 15 | ilam
# Processing Record 7 of Set 15 | tirumullaivasal
# Processing Record 8 of Set 15 | petropavlovka
# Processing Record 9 of Set 15 | ambon
# Processing Record 10 of Set 15 | vadso
# Processing Record 11 of Set 15 | erzin
# Processing Record 12 of Set 15 | dalbandin
# Processing Record 13 of Set 15 | yatou
# Processing Record 14 of Set 15 | morgan city
# Processing Record 15 of Set 15 | puerto leguizamo
# Processing Record 16 of Set 15 | adrar
# Processing Record 17 of Set 15 | puerto del rosario
# Processing Record 18 of Set 15 | misratah
# Processing Record 19 of Set 15 | olavarria
# Processing Record 20 of Set 15 | berbera
# Processing Record 21 of Set 15 | gaurnadi
# Processing Record 22 of Set 15 | male
# Processing Record 23 of Set 15 | brainerd
# Processing Record 24 of Set 15 | singkang
# Processing Record 25 of Set 15 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 26 of Set 15 | cumra
# Processing Record 27 of Set 15 | thinadhoo
# Processing Record 28 of Set 15 | xiongzhou
# Processing Record 29 of Set 15 | visina
# Processing Record 30 of Set 15 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 15 | valdepenas
# Processing Record 32 of Set 15 | margate
# Processing Record 33 of Set 15 | christchurch
# Processing Record 34 of Set 15 | wajir
# Processing Record 35 of Set 15 | port macquarie
# Processing Record 36 of Set 15 | arman
# Processing Record 37 of Set 15 | galle
# Processing Record 38 of Set 15 | camapua
# Processing Record 39 of Set 15 | lincoln
# Processing Record 40 of Set 15 | curup
# Processing Record 41 of Set 15 | champerico
# Processing Record 42 of Set 15 | kuala pilah
# Processing Record 43 of Set 15 | mumford
# Processing Record 44 of Set 15 | kandrian
# Processing Record 45 of Set 15 | port augusta
# Processing Record 46 of Set 15 | sungairaya
# Processing Record 47 of Set 15 | atasu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 689

# %%
city_url = url + "&q=" + "Ushuaia"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -68.3, 'lat': -54.8},
#  'weather': [{'id': 500,
#    'main': 'Rain',
#    'description': 'light rain',
#    'icon': '10n'}],
#  'base': 'stations',
#  'main': {'temp': 35.26,
#   'feels_like': 28.15,
#   'temp_min': 35.26,
#   'temp_max': 35.26,
#   'pressure': 1002,
#   'humidity': 80},
#  'visibility': 10000,
#  'wind': {'speed': 9.22, 'deg': 270},
#  'rain': {'1h': 0.17},
#  'clouds': {'all': 40},
#  'dt': 1633148981,
#  'sys': {'type': 1,
#   'id': 8303,
#   'country': 'AR',
#   'sunrise': 1633168523,
#   'sunset': 1633214961},
#  'timezone': -10800,
#  'id': 3833367,
#  'name': 'Ushuaia',
#  'cod': 200}

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Ushuaia -54.8000  -68.3000     35.26        80          40
# 1           Vada  51.9700    5.6667     57.09        95          75
# 2   Puerto Ayora  -0.7393  -90.3518     68.70        93          71
# 3     Budogoshch  59.2816   32.4707     38.75        96          58
# 4      Cape Town -33.9258   18.4232     57.09        86          75
# 5         Jasper  37.2001  -94.3502     71.65        87          75
# 6          Vaini -21.2000 -175.2000     75.36        83          75
# 7        Mataura -46.1927  168.8643     59.49        69         100
# 8  Marsh Harbour  26.5412  -77.0636     81.12        71          53
# 9      Mingguang  32.7802  117.9638     87.01        50           7
#
#    Wind Speed Country Weather Description                 Date
# 0        9.22      AR          light rain  2021-10-02 04:18:56
# 1        9.22      NL                mist  2021-10-02 04:18:56
# 2        6.89      EC       broken clouds  2021-10-02 04:18:57
# 3        5.12      RU       broken clouds  2021-10-02 04:18:58
# 4        4.61      ZA       moderate rain  2021-10-02 04:18:10
# 5        5.75      US       broken clouds  2021-10-02 04:18:49
# 6       12.66      TO       broken clouds  2021-10-02 04:15:44
# 7        6.35      NZ     overcast clouds  2021-10-02 04:16:44
# 8       20.07      BS       broken clouds  2021-10-02 04:18:59
# 9        8.79      CN          light rain  2021-10-02 04:18:33

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness",
                            "Wind Speed", "Weather Description"]

# %%
city_data_df = city_data_df[new_column_order]

# %%
city_data_df
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0         Ushuaia      AR  2021-10-02 04:18:56 -54.8000  -68.3000     35.26
# 1            Vada      NL  2021-10-02 04:18:56  51.9700    5.6667     57.09
# 2    Puerto Ayora      EC  2021-10-02 04:18:57  -0.7393  -90.3518     68.70
# 3      Budogoshch      RU  2021-10-02 04:18:58  59.2816   32.4707     38.75
# 4       Cape Town      ZA  2021-10-02 04:18:10 -33.9258   18.4232     57.09
# ..            ...     ...                  ...      ...       ...       ...
# 684       Mumford      GH  2021-10-02 04:24:30   5.2618   -0.7590     76.64
# 685      Kandrian      PG  2021-10-02 04:24:31  -6.2167  149.5500     84.76
# 686  Port Augusta      AU  2021-10-02 04:24:31 -32.5000  137.7667     81.72
# 687    Sungairaya      ID  2021-10-02 04:24:32   0.7000  108.9000     77.67
# 688         Atasu      KZ  2021-10-02 04:24:32  48.6814   71.6433     37.08
#
#      Humidity  Cloudiness  Wind Speed Weather Description
# 0          80          40        9.22          light rain
# 1          95          75        9.22                mist
# 2          93          71        6.89       broken clouds
# 3          96          58        5.12       broken clouds
# 4          86          75        4.61       moderate rain
# ..        ...         ...         ...                 ...
# 684        87         100        5.39          light rain
# 685        71         100        5.46          light rain
# 686        20          40       14.50    scattered clouds
# 687        75         100        7.52          light rain
# 688        69          78        8.48       broken clouds
#
# [689 rows x 10 columns]

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
